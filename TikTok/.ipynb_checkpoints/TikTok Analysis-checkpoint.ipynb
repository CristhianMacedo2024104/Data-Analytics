# %% [markdown]
# # TikTok Analysis
#
# **About Dataset**
#
# This is the Dataset of popular hashtags on TikTok, this includes the author name, author id, author signature, comment count, hashtags details, URL, share count, hashtags which i scrape are meme, funny, humor, comedy, education, lol, dance, song, music, etc.
#
# TikTok Dataset - Tiktok popular hashtags datset [link](https://www.kaggle.com/datasets/muhammadanasmahmood/tiktok-dataset)

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# ### 2.1 Importing Libraries

# %%
import pandas as pd 

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.2 Loading Data

# %%
# pip install openpyxl

# %%
df = pd.read_excel("dataset_free-tiktok-scraper_2022-07-27_21-44-20-266.xlsx")

# %% [markdown]
# ### 2.3 Inspecting the Data Set

# %%
df.head()
# Out:
#                                    authorMeta/avatar  authorMeta/digg  \
# 0  https://p16-sign-sg.tiktokcdn.com/aweme/720x72...              420
# 1  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...            10800
# 2  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...              251
# 3  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...              218
# 4  https://p19-sign.tiktokcdn-us.com/tos-useast5-...            47600
#
#    authorMeta/fans  authorMeta/following  authorMeta/heart  \
# 0         13200000                    28         150400000
# 1          1300000                   182          35100000
# 2           696800                    42          15900000
# 3           510200                    56          32100000
# 4          3300000                   690         137300000
#
#          authorMeta/id   authorMeta/name authorMeta/nickName  \
# 0  6713126981665686530          miso_ara       미소아라 Miso_Ara
# 1  6929583089811522566          crinka11        Chris Rinker
# ...

# %%
df.shape
# Out:
# (1200, 52)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 52 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   authorMeta/avatar                       1200 non-null   object
#  1   authorMeta/digg                         1200 non-null   int64
#  2   authorMeta/fans                         1200 non-null   int64
#  3   authorMeta/following                    1200 non-null   int64
#  4   authorMeta/heart                        1200 non-null   int64
#  5   authorMeta/id                           1200 non-null   int64
#  6   authorMeta/name                         1200 non-null   object
#  7   authorMeta/nickName                     1178 non-null   object
#  8   authorMeta/signature                    1142 non-null   object
#  9   authorMeta/verified                     1200 non-null   bool
# ...

# %%
df.describe().T
# Out:
#                                          count          mean           std  \
# authorMeta/digg                         1200.0  1.894140e+04  1.660581e+05
# authorMeta/fans                         1200.0  7.124049e+06  2.096570e+07
# authorMeta/following                    1200.0  5.088200e+02  1.237753e+03
# authorMeta/heart                        1200.0  1.475789e+08  3.599765e+08
# authorMeta/id                           1200.0  5.912425e+18  2.265439e+18
# authorMeta/video                        1200.0  6.187742e+02  1.598082e+03
# commentCount                            1200.0  5.355442e+04  7.413965e+04
# createTime                              1200.0  1.621667e+09  2.622762e+07
# diggCount                               1200.0  6.577728e+06  5.867806e+06
# effectStickers/0/ID                       80.0  4.966965e+05  2.934072e+05
# effectStickers/0/stickerStats/useCount    18.0  0.000000e+00  0.000000e+00
# ...

# %%
df.isnull().sum()
# Out:
# authorMeta/avatar                            0
# authorMeta/digg                              0
# authorMeta/fans                              0
# authorMeta/following                         0
# authorMeta/heart                             0
# authorMeta/id                                0
# authorMeta/name                              0
# authorMeta/nickName                         22
# authorMeta/signature                        58
# authorMeta/verified                          0
# authorMeta/video                             0
# commentCount                                 0
# createTime                                   0
# createTimeISO                                0
# diggCount                                    0
# downloaded                                   0
# effectStickers/0/ID                       1120
# effectStickers/0/name                     1120
# effectStickers/0/stickerStats/useCount    1182
# effectStickers/1/ID                       1184
# ...

# %%
df.isnull().mean() * 100
# Out:
# authorMeta/avatar                          0.000000
# authorMeta/digg                            0.000000
# authorMeta/fans                            0.000000
# authorMeta/following                       0.000000
# authorMeta/heart                           0.000000
# authorMeta/id                              0.000000
# authorMeta/name                            0.000000
# authorMeta/nickName                        1.833333
# authorMeta/signature                       4.833333
# authorMeta/verified                        0.000000
# authorMeta/video                           0.000000
# commentCount                               0.000000
# createTime                                 0.000000
# createTimeISO                              0.000000
# diggCount                                  0.000000
# downloaded                                 0.000000
# effectStickers/0/ID                       93.333333
# effectStickers/0/name                     93.333333
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (20, 4))
(1 - df.isnull().mean()).abs().plot.bar(ax = ax, colormap = 'Pastel2');

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# authorMeta/nickName                         22
# authorMeta/signature                        58
# effectStickers/0/ID                       1120
# effectStickers/0/name                     1120
# effectStickers/0/stickerStats/useCount    1182
# effectStickers/1/ID                       1184
# effectStickers/1/name                     1184
# effectStickers/1/stickerStats/useCount    1195
# hashtags/0/cover                          1052
# hashtags/0/id                                2
# hashtags/0/name                              3
# hashtags/0/title                           880
# hashtags/1/cover                          1090
# hashtags/1/id                               19
# hashtags/1/name                             22
# hashtags/1/title                           923
# mediaUrls/0                                  2
# mentions/0                                 968
# mentions/1                                1155
# mentions/2                                1187
# ...

# %%
df.isnull().mean()[df.isnull().mean() > 0.2]
# Out:
# effectStickers/0/ID                       0.933333
# effectStickers/0/name                     0.933333
# effectStickers/0/stickerStats/useCount    0.985000
# effectStickers/1/ID                       0.986667
# effectStickers/1/name                     0.986667
# effectStickers/1/stickerStats/useCount    0.995833
# hashtags/0/cover                          0.876667
# hashtags/0/title                          0.733333
# hashtags/1/cover                          0.908333
# hashtags/1/title                          0.769167
# mentions/0                                0.806667
# mentions/1                                0.962500
# mentions/2                                0.989167
# mentions/3                                0.996667
# mentions/4                                0.998333
# mentions/5                                0.999167
# musicMeta/musicAlbum                      0.732500
# dtype: float64

# %%
df[df.duplicated()].shape
# Out:
# (0, 52)

# %% [markdown]
# ### 2.4 Analyzing Values / Finding Unique Values

# %%
df["hashtags/1/title"].unique()
# Out:
# array(['Woah woah woah, stop right there!  Have you done the latest dance challange yet!  Dab, floss, or just show off your moves with the #WoahChallenge!',
#        nan, "TikTok's Funniest Home Videos!", "What's so #Funny?",
#        'All the soothing sounds you need to massage your brain.',
#        'Asla bir sonraki hamleni bilmelerine izin verme!',
#        'Make the ultimate collab with your fav creators with our brand new feature, #STITCH! Just find a TikTok video you love, press share, and send it to Stitch.',
#        "It's #Fail time",
#        'From start to finish, show us your latest #DIYProject.',
#        'From places to people, show us what makes up #Australia.',
#        "Whether you're a professional DJ or just control the aux, use our new Creative Effect and show us what happens when the beat drops.",
#        '¡Llegaste al lugar indicado para encontrar memazos! \n\nCada viernes podrás encontrar a los 9 #MEMESTikTok oficiales de la semana.',
# ...

# %% [markdown]
# ### 2.5 Overview

# %% [markdown]
# ## 3. Data Preparation

# %% [markdown]
# ## 3.1 Dropping Irrelevant Columns

# %%
# df.isnull().mean()[df.isnull().mean() > 0.2]

# %%
# df = df.drop(columns = ["effectStickers/0/ID", "effectStickers/0/name", "effectStickers/0/stickerStats/useCount", 
#                        "effectStickers/1/ID", "effectStickers/1/name", "effectStickers/1/stickerStats/useCount",
#                        "hashtags/0/cover", "hashtags/0/title", "hashtags/1/cover", "hashtags/1/title", "mentions/0",
#                        "mentions/1", "mentions/2", "mentions/3", "mentions/4", "mentions/5", "musicMeta/musicAlbum"])

# %%
# df.head()

# %% [markdown]
# ### 3.2 Renaming Columns

# %%
# df.columns
